# %% [markdown]
# ### [Metacode] 유통/이커머스 데이터 분석 입문 포트폴리오 만들기

# %% [markdown]
# ### 1차 프로젝트 : Addidas 미국 판매데이터 분석 - part1
#
#  데이터 출처: Kaggle(https://www.kaggle.com/datasets/heemalichaudhari/adidas-sales-dataset)

# %%
#for google dirve mount in colab
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## (1)데이터 로드 및 확인

# %%
import pandas as pd
import numpy as np

adidas = pd.read_csv('Adidas_US_Sales_Datasets.csv')

# %%
adidas.head(10)
# Out:
#       Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker      1185732   2020-01-01  Northeast  New York  New York
# 1  Foot Locker      1185732   2020-01-02  Northeast  New York  New York
# 2  Foot Locker      1185732   2020-01-03  Northeast  New York  New York
# 3  Foot Locker      1185732   2020-01-04  Northeast  New York  New York
# 4  Foot Locker      1185732   2020-01-05  Northeast  New York  New York
# 5  Foot Locker      1185732   2020-01-06  Northeast  New York  New York
# 6  Foot Locker      1185732   2020-01-07  Northeast  New York  New York
# 7  Foot Locker      1185732   2020-01-08  Northeast  New York  New York
# 8  Foot Locker      1185732   2020-01-21  Northeast  New York  New York
# 9  Foot Locker      1185732   2020-01-22  Northeast  New York  New York
#
#                      Product Price per Unit Units Sold Total Sales  \
# 0      Men's Street Footwear        $50.00       1,200   $600,000
# ...

# %% [markdown]
# - Retailer: adidas 브랜드를 판매하는 유통처
# - Retailer ID: 판매점 ID
# - Price per Unit: 상품 1개당 가격
# - Units Sold: 판매수량
# - Total Sales: 판매금액
# - Operating Profit: 영업이익(매출액 원가)
# - Operating Margin: 영업마진(영업이익률)

# %%
adidas['Sales Method'].unique()
# Out:
# array(['In-store', 'Outlet', 'Online'], dtype=object)

# %%
adidas.info() #데이터 타입 조회
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9648 non-null   object
#  1   Retailer ID       9648 non-null   int64
#  2   Invoice Date      9648 non-null   object
#  3   Region            9648 non-null   object
#  4   State             9648 non-null   object
#  5   City              9648 non-null   object
#  6   Product           9648 non-null   object
#  7   Price per Unit    9648 non-null   object
#  8   Units Sold        9648 non-null   object
#  9   Total Sales       9648 non-null   object
#  10  Operating Profit  9648 non-null   object
#  11  Operating Margin  9648 non-null   object
#  12  Sales Method      9648 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 980.0+ KB

# %% [markdown]
# ## (2)데이터 전처리
#
# 데이터 타입 변환
#
# - Retailer ID int64 -> 문자
# - Invoice Date Object -> 날짜
# - Price per Unit object -> 숫자(실수, float)
# - Units Sold object -> 숫자(실수, float)
# - Total Sales object -> 숫자(실수, float)
# - Operating Profit object -> 숫자(실수, float)
# - Operating Margin onject -> 숫자(실수, float)

# %% [markdown]
# ### 숫자가 문자로 나타난 경우 문자를 숫자로 변환

# %%
adidas['Price per Unit'].astpe('float')

#Error 발생 문자형태인 object는 int 변환이 불가능하다
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 adidas['Price per Unit'].astpe('float')
#       3 #Error 발생 문자형태인 object는 int 변환이 불가능하다
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'astpe'

# %% [markdown]
# Pandas 데이터프레임내 문자 변환
#
# - DataFrame['컬럼명].str. 메소드 형태로 문자열 함수 사용
# - 현재 가격, 매출액 등의 컬럼에는 모두 특수문자 '%', '$', ',' 가 포함되어있음
#
# 정규표현식을 사용하여 특수문자 전체를 제거하는 법
# - adidas['Price per Unit'].str.replace('[\W]', ", regex=True)
# - [\W] : 숫자, 문자를 제외한 나머지(특수문자)를 의미
#
# 하지만, 이 경우 소수점이 있기 때문에 특수문자 전체를 제거하면 안됨
#
# - adidas['Price per Unit'].str.replace(['%$,'], '')
# - 대괄호 [] 안에 있는 문자들을 공백으로 대체

# %%
adidas['Price per Unit'] = adidas['Price per Unit'].str.replace('[%$,]', '', regex=True).str.strip().astype(float)
adidas['Units Sold'] = adidas['Units Sold'].str.replace('[%$,]', '', regex=True).str.strip().astype(float)
adidas['Total Sales'] = adidas['Total Sales'].str.replace('[%$,]', '', regex=True).str.strip().astype(float)
adidas['Operating Profit'] = adidas['Operating Profit'].str.replace('[%$,]', '', regex=True).str.strip().astype(float)
adidas['Operating Margin'] = adidas['Operating Margin'].str.replace('[%$,]', '', regex=True).str.strip().astype(float)

# %%
adidas.head(10)
# Out:
#       Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker      1185732   2020-01-01  Northeast  New York  New York
# 1  Foot Locker      1185732   2020-01-02  Northeast  New York  New York
# 2  Foot Locker      1185732   2020-01-03  Northeast  New York  New York
# 3  Foot Locker      1185732   2020-01-04  Northeast  New York  New York
# 4  Foot Locker      1185732   2020-01-05  Northeast  New York  New York
# 5  Foot Locker      1185732   2020-01-06  Northeast  New York  New York
# 6  Foot Locker      1185732   2020-01-07  Northeast  New York  New York
# 7  Foot Locker      1185732   2020-01-08  Northeast  New York  New York
# 8  Foot Locker      1185732   2020-01-21  Northeast  New York  New York
# 9  Foot Locker      1185732   2020-01-22  Northeast  New York  New York
#
#                      Product  Price per Unit  Units Sold  Total Sales  \
# 0      Men's Street Footwear            50.0      1200.0     600000.0
# ...

# %%
adidas['Operating_Margin_rate'] = adidas['Operating Margin']*0.01
adidas.head()
# Out:
#       Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker      1185732   2020-01-01  Northeast  New York  New York
# 1  Foot Locker      1185732   2020-01-02  Northeast  New York  New York
# 2  Foot Locker      1185732   2020-01-03  Northeast  New York  New York
# 3  Foot Locker      1185732   2020-01-04  Northeast  New York  New York
# 4  Foot Locker      1185732   2020-01-05  Northeast  New York  New York
#
#                      Product  Price per Unit  Units Sold  Total Sales  \
# 0      Men's Street Footwear            50.0      1200.0     600000.0
# 1    Men's Athletic Footwear            50.0      1000.0     500000.0
# 2    Women's Street Footwear            40.0      1000.0     400000.0
# 3  Women's Athletic Footwear            45.0       850.0     382500.0
# 4              Men's Apparel            60.0       900.0     540000.0
#
#    Operating Profit  Operating Margin Sales Method  Operating_Margin_rate
# ...

# %% [markdown]
# ## 2) Pandas 시간데이터 다루기
#
# YYYY-mm-dd 형태의 문자 데이터를 pandas의 datetime으로 변환
#
# '%Y-%m-%d'
#
# 만약 19990101와 같은 형태라면
#
# %Y%m%d

# %%
adidas.head()
# Out:
#       Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker      1185732   2020-01-01  Northeast  New York  New York
# 1  Foot Locker      1185732   2020-01-02  Northeast  New York  New York
# 2  Foot Locker      1185732   2020-01-03  Northeast  New York  New York
# 3  Foot Locker      1185732   2020-01-04  Northeast  New York  New York
# 4  Foot Locker      1185732   2020-01-05  Northeast  New York  New York
#
#                      Product  Price per Unit  Units Sold  Total Sales  \
# 0      Men's Street Footwear            50.0      1200.0     600000.0
# 1    Men's Athletic Footwear            50.0      1000.0     500000.0
# 2    Women's Street Footwear            40.0      1000.0     400000.0
# 3  Women's Athletic Footwear            45.0       850.0     382500.0
# 4              Men's Apparel            60.0       900.0     540000.0
#
#    Operating Profit  Operating Margin Sales Method  Operating_Margin_rate
# ...

# %%
adidas['Invoice Date'] = pd.to_datetime(adidas['Invoice Date'], format = '%Y-%m-%d')

# %%
adidas['year'] = adidas['Invoice Date'].dt.year
adidas['month'] = adidas['Invoice Date'].dt.month

# %%
# 년, 월 추가
adidas.head()
# Out:
#       Retailer  Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker      1185732   2020-01-01  Northeast  New York  New York
# 1  Foot Locker      1185732   2020-01-02  Northeast  New York  New York
# 2  Foot Locker      1185732   2020-01-03  Northeast  New York  New York
# 3  Foot Locker      1185732   2020-01-04  Northeast  New York  New York
# 4  Foot Locker      1185732   2020-01-05  Northeast  New York  New York
#
#                      Product  Price per Unit  Units Sold  Total Sales  \
# 0      Men's Street Footwear            50.0      1200.0     600000.0
# 1    Men's Athletic Footwear            50.0      1000.0     500000.0
# 2    Women's Street Footwear            40.0      1000.0     400000.0
# 3  Women's Athletic Footwear            45.0       850.0     382500.0
# 4              Men's Apparel            60.0       900.0     540000.0
#
#    Operating Profit  Operating Margin Sales Method  Operating_Margin_rate  \
# ...

# %% [markdown]
# ## 3)문자를 숫자로 반환

# %%
adidas['Retailer ID'] = adidas['Retailer ID'].astype('string')

# %% [markdown]
# ## 4)결측치 처리

# %%
adidas.isnull().sum() # 결측치 없음
# Out:
# Retailer                 0
# Retailer ID              0
# Invoice Date             0
# Region                   0
# State                    0
# City                     0
# Product                  0
# Price per Unit           0
# Units Sold               0
# Total Sales              0
# Operating Profit         0
# Operating Margin         0
# Sales Method             0
# Operating_Margin_rate    0
# year                     0
# month                    0
# dtype: int64

# %%
adidas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9648 entries, 0 to 9647
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Retailer               9648 non-null   object
#  1   Retailer ID            9648 non-null   string
#  2   Invoice Date           9648 non-null   datetime64[ns]
#  3   Region                 9648 non-null   object
#  4   State                  9648 non-null   object
#  5   City                   9648 non-null   object
#  6   Product                9648 non-null   object
#  7   Price per Unit         9648 non-null   float64
#  8   Units Sold             9648 non-null   float64
#  9   Total Sales            9648 non-null   float64
#  10  Operating Profit       9648 non-null   float64
#  11  Operating Margin       9648 non-null   float64
#  12  Sales Method           9648 non-null   object
#  13  Operating_Margin_rate  9648 non-null   float64
# ...

# %% [markdown]
# ## (3)데이터 분석-1

# %% [markdown]
# ### 월별 판매량 분석

# %%
adidas.describe()
# Out:
#                         Invoice Date  Price per Unit   Units Sold  \
# count                           9648     9648.000000  9648.000000
# mean   2021-05-10 15:20:44.776119296       45.216625   256.930037
# min              2020-01-01 00:00:00        7.000000     0.000000
# 25%              2021-02-17 00:00:00       35.000000   106.000000
# 50%              2021-06-04 00:00:00       45.000000   176.000000
# 75%              2021-09-16 00:00:00       55.000000   350.000000
# max              2021-12-31 00:00:00      110.000000  1275.000000
# std                              NaN       14.705397   214.252030
#
#          Total Sales  Operating Profit  Operating Margin  \
# count    9648.000000       9648.000000       9648.000000
# mean    93273.437500      34425.282131         42.299129
# min         0.000000          0.000000         10.000000
# 25%      4254.500000       1922.000000         35.000000
# 50%      9576.000000       4371.500000         41.000000
# ...

# %% [markdown]
# ### 월별 판매량 그래프

# %%
adidas.groupby(['year', 'month'])['Units Sold'].sum().plot().line()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 adidas.groupby(['year', 'month'])['Units Sold'].sum().plot().line()
#
# AttributeError: 'Axes' object has no attribute 'line'

# %% [markdown]
# 2021년 1월 부터 판매량 급등

# %%
adidas.groupby(['year', 'month'])['Units Sold'].sum()
# Out:
# year  month
# 2020  1         48333.0
#       2         37846.0
#       3         46972.0
#       4         54709.0
#       5         35705.0
#       6         16269.0
#       7         38219.0
#       8         62307.0
#       9         46125.0
#       10        30167.0
#       11        25152.0
#       12        20545.0
# 2021  1        179299.0
#       2        156113.0
#       3        143988.0
#       4        161717.0
#       5        178900.0
#       6        164745.0
#       7        180481.0
#       8        195414.0
#       9        182425.0
#       10       152834.0
#       11       149350.0
#       12       171246.0
# Name: Units Sold, dtype: float64

# %%
adidas.pivot_table(index = 'year', columns= 'month', values= 'Units Sold', aggfunc= 'sum')
# Out:
# month        1         2         3         4         5         6         7   \
# year
# 2020    48333.0   37846.0   46972.0   54709.0   35705.0   16269.0   38219.0
# 2021   179299.0  156113.0  143988.0  161717.0  178900.0  164745.0  180481.0
#
# month        8         9         10        11        12
# year
# 2020    62307.0   46125.0   30167.0   25152.0   20545.0
# 2021   195414.0  182425.0  152834.0  149350.0  171246.0

# %% [markdown]
# 소매업체별 분석

# %%
adidas.pivot_table(index = 'year', columns= 'Retailer', values= 'Units Sold', aggfunc= 'sum')
# Out:
# Retailer    Amazon  Foot Locker    Kohl's  Sports Direct   Walmart  West Gear
# year
# 2020           NaN     120304.0    2214.0        46266.0   99798.0   193767.0
# 2021      197990.0     484065.0  285161.0       511374.0  106427.0   431495.0

# %%
adidas.pivot_table(index = ['year', 'month'], columns= 'Retailer', values= 'Units Sold', aggfunc= 'sum')
# Out:
# Retailer     Amazon  Foot Locker   Kohl's  Sports Direct  Walmart  West Gear
# year month
# 2020 1          NaN      30275.0      NaN            NaN      NaN    18058.0
#      2          NaN      14712.0      NaN            NaN      NaN    23134.0
#      3          NaN      27650.0      NaN            NaN      NaN    19322.0
#      4          NaN       2216.0      NaN            NaN  22146.0    30347.0
#      5          NaN       2071.0      NaN         4584.0  10950.0    18100.0
#      6          NaN          NaN      NaN            NaN      NaN    16269.0
#      7          NaN          NaN      NaN        15198.0   1630.0    21391.0
#      8          NaN      17796.0      NaN        10337.0  29676.0     4498.0
#      9          NaN       5625.0      NaN         6203.0  19619.0    14678.0
#      10         NaN       4446.0      NaN         9944.0  15777.0        NaN
#      11         NaN       8193.0      NaN            NaN      NaN    16959.0
# ...

# %%
adidas.pivot_table(index = ['year', 'month'], columns= 'Retailer', values= 'Units Sold', aggfunc= 'sum').plot.line()
# Out:
# <Axes: xlabel='year,month'>

# %%
adidas[['Retailer', 'Retailer ID']].drop_duplicates().sort_values('Retailer')
# 소매브랜드 안에도 ID가 여러개 있음(해당 소매점 브랜드의 점포 ID로 보임)
# Out:
#            Retailer Retailer ID
# 1148         Amazon     1185732
# 2007    Foot Locker     1197831
# 1287    Foot Locker     1128299
# 0       Foot Locker     1185732
# 212          Kohl's     1189833
# 2147         Kohl's     1128299
# 1499         Kohl's     1185732
# 2786         Kohl's     1197831
# 766   Sports Direct     1185732
# 68    Sports Direct     1197831
# 1355  Sports Direct     1128299
# 1333        Walmart     1128299
# 46          Walmart     1185732
# 90          Walmart     1197831
# 140       West Gear     1128299
# 725       West Gear     1185732
# 2012      West Gear     1197831

# %% [markdown]
# 월별로 상점의 숫자는 어떻게 될까?
#
# 예) 2020년에는 Foot Locker의 상점 수가 1개였는데 2021년에는 3개로 늘지 않았을까?

# %%
df = adidas[['Retailer', 'Retailer ID', 'year', 'month']].drop_duplicates().sort_values(['Retailer', 'year', 'month'])
df
# Out:
#        Retailer Retailer ID  year  month
# 1224     Amazon     1185732  2021      1
# 1225     Amazon     1185732  2021      2
# 1231     Amazon     1185732  2021      3
# 1237     Amazon     1185732  2021      4
# 1243     Amazon     1185732  2021      5
# ...         ...         ...   ...    ...
# 1923  West Gear     1128299  2021     11
# 2715  West Gear     1197831  2021     11
# 1427  West Gear     1128299  2021     12
# 1497  West Gear     1185732  2021     12
# 2721  West Gear     1197831  2021     12
#
# [211 rows x 4 columns]

# %%
df.pivot_table(index=['year', 'month'], values= 'Retailer ID', aggfunc= 'count')
# Out:
#             Retailer ID
# year month
# 2020 1                2
#      2                2
#      3                2
#      4                4
#      5                4
#      6                1
#      7                3
#      8                5
#      9                4
#      10               3
#      11               2
#      12               3
# 2021 1               14
#      2               15
#      3               15
#      4               15
#      5               15
#      6               13
#      7               15
#      8               16
#      9               15
#      10              16
#      11              14
#      12              13

# %%
df.pivot_table(index=['year', 'month'], values= 'Retailer ID', aggfunc= 'count').plot(kind = 'line', figsize=(15, 4))
# Out:
# <Axes: xlabel='year,month'>

# %%
df.pivot_table(index=['year', 'month'], columns='Retailer', values= 'Retailer ID', aggfunc= 'count')
# Out:
# Retailer    Amazon  Foot Locker  Kohl's  Sports Direct  Walmart  West Gear
# year month
# 2020 1         NaN          1.0     NaN            NaN      NaN        1.0
#      2         NaN          1.0     NaN            NaN      NaN        1.0
#      3         NaN          1.0     NaN            NaN      NaN        1.0
#      4         NaN          1.0     NaN            NaN      1.0        2.0
#      5         NaN          1.0     NaN            1.0      1.0        1.0
#      6         NaN          NaN     NaN            NaN      NaN        1.0
#      7         NaN          NaN     NaN            1.0      1.0        1.0
#      8         NaN          1.0     NaN            1.0      1.0        2.0
#      9         NaN          1.0     NaN            1.0      1.0        1.0
#      10        NaN          1.0     NaN            1.0      1.0        NaN
#      11        NaN          1.0     NaN            NaN      NaN        1.0
# ...

# %%
df.pivot_table(index=['year', 'month'], columns='Retailer', values= 'Retailer ID', aggfunc= 'count').plot(kind='area', figsize=(20,7))
# Out:
# <Axes: xlabel='year,month'>

# %% [markdown]
# 아디다스는 2020년 코로나로 인해 매출액이 하락했다가 2021년도에 회복세였음
#
# https://www.statista.com/statistics/268416/net-sales-of-the-adidas-group-worldwide-since-2000/

# %% [markdown]
# # 2차 프로젝트: Adidas 미국 판매데이터 분석 - 파트2

# %% [markdown]
# ## (4) 데이터분석-2

# %% [markdown]
# ### 마진율 분석

# %%
adidas.head()
# Out:
#       Retailer Retailer ID Invoice Date     Region     State      City  \
# 0  Foot Locker     1185732   2020-01-01  Northeast  New York  New York
# 1  Foot Locker     1185732   2020-01-02  Northeast  New York  New York
# 2  Foot Locker     1185732   2020-01-03  Northeast  New York  New York
# 3  Foot Locker     1185732   2020-01-04  Northeast  New York  New York
# 4  Foot Locker     1185732   2020-01-05  Northeast  New York  New York
#
#                      Product  Price per Unit  Units Sold  Total Sales  \
# 0      Men's Street Footwear            50.0      1200.0     600000.0
# 1    Men's Athletic Footwear            50.0      1000.0     500000.0
# 2    Women's Street Footwear            40.0      1000.0     400000.0
# 3  Women's Athletic Footwear            45.0       850.0     382500.0
# 4              Men's Apparel            60.0       900.0     540000.0
#
#    Operating Profit  Operating Margin Sales Method  Operating_Margin_rate  \
# ...

# %%
adidas.groupby('year').agg({'Operating_Margin_rate' : 'mean'})
# Out:
#       Operating_Margin_rate
# year
# 2020               0.403733
# 2021               0.425996

# %%
adidas.pivot_table(index = ['year', 'month'], values= 'Operating_Margin_rate', aggfunc='mean').plot()
# 6월 마진율이 심히 안좋다는 것을 알 수 있다.
# Out:
# <Axes: xlabel='year,month'>

# %%
# 기간에 따른 업체별 마진율 확인
adidas.pivot_table(index = ['year', 'month'], columns='Retailer', values= 'Operating_Margin_rate', aggfunc='mean').plot(figsize=(15,4))
# Out:
# <Axes: xlabel='year,month'>

# %% [markdown]
# ### 판매방법에 따른 마진율/판매단가

# %%
adidas.pivot_table(index=['year','month'], columns='Sales Method', values= 'Operating_Margin_rate', aggfunc='mean').plot(kind='bar', figsize=(15,7))
adidas.pivot_table(index=['year','month'], columns='Sales Method', values= 'Operating_Margin_rate', aggfunc='mean').plot(kind='bar', figsize=(15,7),stacked=True)
# Out:
# <Axes: xlabel='year,month'>

# %%
adidas.pivot_table(index=['year','month'], columns='Sales Method', values= 'Price per Unit', aggfunc='mean').plot(kind='line', figsize=(15,7))
# Out:
# <Axes: xlabel='year,month'>

# %% [markdown]
# ## 판매방법에 따라 판매성과에 차이가 있을까? (분석 분석)
#
# 일원배치 분산분석(ANOVA)을 이용한 통계적 검증
#
# 세개 이상의 집단이 하나의 변수로 인해 차이가 나는지 검증하는 분석방법
#
# 최소자승법(OLS)를 이용하여 검증할 수 있음

# %% [markdown]
# ### BoxPlot을 이용한 시각화

# %%
adidas[['Sales Method', 'Price per Unit']].boxplot(by = 'Sales Method')
# Out:
# <Axes: title={'center': 'Price per Unit'}, xlabel='[Sales Method]'>

# %%
adidas[['Sales Method', 'Operating_Margin_rate']].boxplot(by = 'Sales Method')
# Out:
# <Axes: title={'center': 'Operating_Margin_rate'}, xlabel='[Sales Method]'>

# %% [markdown]
# ### Anova 함수

# %%
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

# %%
# x: 비교그룹(매장, 온라인, 아울렛) -> Sales Method
# y: 비교할 변수 -> 영업이익, 단가
x = 'Sales Method'
y = 'Operating_Margin_rate'

# %%
df = adidas[[x, y]]
df
# Out:
#      Sales Method  Operating_Margin_rate
# 0        In-store                   0.50
# 1        In-store                   0.30
# 2        In-store                   0.35
# 3        In-store                   0.35
# 4        In-store                   0.30
# ...           ...                    ...
# 9643       Outlet                   0.28
# 9644       Outlet                   0.32
# 9645       Outlet                   0.37
# 9646       Outlet                   0.42
# 9647       Outlet                   0.27
#
# [9648 rows x 2 columns]

# %%
# 띄어쓰기가 있는 경우 statsmodels의 ols 함수가 인식 못함
# 띄어쓰기를 _로 바꿈

x = x.replace(' ', '_')
y = y.replace(' ', '_')
print('replaced names', x,':', y)
# Out:
# replaced names Sales_Method : Operating_Margin_rate

# %%
df.columns = [x, y]

# %%
# the "C" indicates categorical data
model = ols(f'{y} ~C({x})', df).fit()

# %%
anova_tb = anova_lm(model)
print(anova_tb)
# Out:
#                      df     sum_sq   mean_sq            F  PR(>F)
# C(Sales_Method)     2.0  18.450217  9.225109  1224.079115     0.0
# Residual         9645.0  72.688254  0.007536          NaN     NaN

# %%
# 유의 확률에 따른 가설 확인
if anova_tb.iloc[0,4]<0.05:
    print(f'판매방법에 따른 {y}이(가) 차이가 있습니다.')
else:
    print(f'판매방법에 따른 {y}이(가) 차이가 없습니다.')
# Out:
# 판매방법에 따른 Operating_Margin_rate이(가) 차이가 있습니다.

# %%
def anova_analysis(x,y):
    df = adidas[[x, y]]

    x = x.replace(' ', '_')
    y = y.replace(' ', '_')
    print('replaced names', x,':', y)

    df.columns = [x, y]

    model = ols(f'{y} ~C({x})', df).fit()
    
    anova_tb = anova_lm(model)
    print(anova_tb)

    if anova_tb.iloc[0,4]<0.05:
        print(f'판매방법에 따른 {y}이(가) 차이가 있습니다.')
    else:
        print(f'판매방법에 따른 {y}이(가) 차이가 없습니다.')

# %%
print('판매가격의 차이 검증')
anova_analysis('Sales Method', 'Price per Unit')
print('\r\n\r\n')
print('====================================================================')
print('\r\n\r\n')
print('마진율의 차이 검증')
anova_analysis('Sales Method', 'Operating_Margin_rate')
# Out:
# 판매가격의 차이 검증
# replaced names Sales_Method : Price_per_Unit
#                      df        sum_sq       mean_sq           F        PR(>F)
# C(Sales_Method)     2.0  5.550261e+04  27751.304281  131.810754  3.339384e-57
# Residual         9645.0  2.030649e+06    210.538999         NaN           NaN
# 판매방법에 따른 Price_per_Unit이(가) 차이가 있습니다.
#
#
#
# ...
#
#
#
# 마진율의 차이 검증
# replaced names Sales_Method : Operating_Margin_rate
#                      df     sum_sq   mean_sq            F  PR(>F)
# C(Sales_Method)     2.0  18.450217  9.225109  1224.079115     0.0
# Residual         9645.0  72.688254  0.007536          NaN     NaN
# 판매방법에 따른 Operating_Margin_rate이(가) 차이가 있습니다.

# %% [markdown]
# => 판매방법에 따라 단가 차이가 있다. In-Store > On-line > Outlet 순
#
# =>즉, 매장 방법 손님의 객단가가 가장 높고, 다음으로 온라인, 아웃렛 순으로 높음 => 할인율이 높다는 의미는 아님
#
# =>아울렛은 매장, 온라인에서 판매되지 않는 상품이 판매되기 때문에 인사이트 분석을 위한 비교대상으 로 보기 어려움
#
# => 판매방법에 따라 마진율(이익율) 차이가 있다. On-line > Outlet > In-Store 순

# %% [markdown]
# 분석 결과
#
# => 온라인 : 단가 낮은 상품이 많이 팔리고, 마진율(이익율)은 높음
#
# => 매장 : 단가 높은 상품 많이 팔리고, 마진율(이익율)도 낮음
#
# 온/오프라인 판매전략 수립에 활용
